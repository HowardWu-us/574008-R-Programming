# %%
install.packages(c("titanic"))
library(titanic)
library(dplyr)
library(ggplot2)
# Out:
# 將程式套件安載入 ‘/opt/homebrew/lib/R/4.4/site-library’
# (因為 ‘lib’ 沒有被指定)
#
#
# 載入套件：‘dplyr’
#
#
# 下列物件被遮斷自 ‘package:stats’:
#
#     filter, lag
#
#
# 下列物件被遮斷自 ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
data(package = 'titanic')
# Out:
# Data sets in package ‘titanic’:
#
# titanic_gender_class_model
#                         Titanic gender class model data.
# titanic_gender_model    Titanic gender model data.
# titanic_test            Titanic test data.
# titanic_train           Titanic train data.

# %%
dim(titanic_train)
# Out:
# [1] 891  12

# %%
names(titanic_train)
# Out:
#  [1] "PassengerId" "Survived"    "Pclass"      "Name"        "Sex"
#  [6] "Age"         "SibSp"       "Parch"       "Ticket"      "Fare"
# [11] "Cabin"       "Embarked"

# %%
ggplot(data = titanic_train, aes(x=Pclass, fill=factor(Survived))) + geom_bar()
# Out:
# plot without title

# %%
ggsave("lab01.png")
# Out:
# Saving 7 x 7 in image
